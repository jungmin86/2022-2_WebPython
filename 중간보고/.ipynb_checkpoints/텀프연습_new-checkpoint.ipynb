# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import matplotlib as mt
from matplotlib import rc

# %%
rc('font', family='AppleGothic')

# %%
group = pd.read_csv('fulldata_10_42_01_P_체력단련장업.csv', chunksize = 1000, encoding='cp949')

# %%
group = list(group)

# %%
df = pd.concat(group)

# %%
Seoul = df[['사업장명', '인허가일자', '인허가취소일자','휴업시작일자', '휴업종료일자', '폐업일자', '영업상태명', '도로명전체주소']]
Seoul.to_csv("헬스장현황_가공.csv", mode = 'w', encoding = 'cp949')

# %%
df1 = pd.read_csv('헬스장현황_가공.csv', encoding='cp949')

# %%
df1
# Out:
#        Unnamed: 0           사업장명     인허가일자     인허가취소일자      휴업시작일자  \
# 0               0       우먼파워에어로빅  20080923         NaN         NaN
# 1               1        홍농 헬스클럽  20030212  20200622.0         NaN
# 2               2      리더스 스포츠클럽  20060612  20200608.0         NaN
# 3               3           태정헬스  20071107  20200608.0         NaN
# 4               4         탑 휘트니스  20040331  20131221.0         NaN
# ...           ...            ...       ...         ...         ...
# 20745       20745          스파르타짐  20100125         NaN         NaN
# 20746       20746  (주)스포츠아트필피트니스  20081104         NaN  20130508.0
# 20747       20747      디앤브이 피트니스  20170504         NaN  20191010.0
# 20748       20748  대영청소년문화진흥원(주)  20090224         NaN         NaN
# 20749       20749         대성오아시스  20090302         NaN         NaN
#
#            휴업종료일자  폐업일자           영업상태명  \
# 0             NaN   NaN  취소/말소/만료/정지/중지
# 1             NaN   NaN  취소/말소/만료/정지/중지
# ...

# %%
df1['폐업,전출,휴업,취소,말소여부'] = np.where(df1['인허가취소일자'].notnull() | df1['휴업시작일자'].notnull() | df1['폐업일자'].notnull(), 1, 0)

# %%
df1.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df1.loc[:, '폐업,전출,휴업,취소,말소연도'] = df1.loc[:, ['인허가취소일자', '폐업일자', '휴업시작일자']].max(axis=1)

# %%
df1['인허가일자'] = pd.to_datetime(df1['인허가일자'], format='%Y%m%d')
df1['인허가취소일자'] = pd.to_datetime(df1['인허가취소일자'],  format='%Y%m%d')
df1['폐업일자'] = pd.to_datetime(df1['폐업일자'],  format='%Y%m%d')
df1['휴업시작일자'] = pd.to_datetime(df1['휴업시작일자'],  format='%Y%m%d')
df1['휴업종료일자'] = pd.to_datetime(df1['휴업종료일자'],  format='%Y%m%d')
df1['폐업,전출,휴업,취소,말소연도'] = pd.to_datetime(df1['폐업,전출,휴업,취소,말소연도'],  format='%Y%m%d')

# %%
df1
# Out:
#                 사업장명      인허가일자    인허가취소일자     휴업시작일자     휴업종료일자 폐업일자  \
# 0           우먼파워에어로빅 2008-09-23        NaT        NaT        NaT  NaT
# 1            홍농 헬스클럽 2003-02-12 2020-06-22        NaT        NaT  NaT
# 2          리더스 스포츠클럽 2006-06-12 2020-06-08        NaT        NaT  NaT
# 3               태정헬스 2007-11-07 2020-06-08        NaT        NaT  NaT
# 4             탑 휘트니스 2004-03-31 2013-12-21        NaT        NaT  NaT
# ...              ...        ...        ...        ...        ...  ...
# 20745          스파르타짐 2010-01-25        NaT        NaT        NaT  NaT
# 20746  (주)스포츠아트필피트니스 2008-11-04        NaT 2013-05-08 2013-09-01  NaT
# 20747      디앤브이 피트니스 2017-05-04        NaT 2019-10-10 2020-10-09  NaT
# 20748  대영청소년문화진흥원(주) 2009-02-24        NaT        NaT        NaT  NaT
# 20749         대성오아시스 2009-03-02        NaT        NaT        NaT  NaT
#
#                 영업상태명                                            도로명전체주소  \
# ...

# %%
df1['폐업,전출,휴업,취소,말소연월'] = df1['폐업,전출,휴업,취소,말소연도'].dt.to_period('M')

# %%
df1['인허가연월'] = df1['인허가일자'].dt.to_period('M')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20750 entries, 0 to 20749
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   사업장명              20750 non-null  object
#  1   인허가일자             20750 non-null  datetime64[ns]
#  2   인허가취소일자           17 non-null     datetime64[ns]
#  3   휴업시작일자            31 non-null     datetime64[ns]
#  4   휴업종료일자            31 non-null     datetime64[ns]
#  5   폐업일자              7695 non-null   datetime64[ns]
#  6   영업상태명             20750 non-null  object
#  7   도로명전체주소           19973 non-null  object
#  8   폐업,전출,휴업,취소,말소여부  20750 non-null  int64
#  9   폐업,전출,휴업,취소,말소연도  7743 non-null   datetime64[ns]
#  10  폐업,전출,휴업,취소,말소연월  7743 non-null   period[M]
#  11  인허가연월             20750 non-null  period[M]
# dtypes: datetime64[ns](6), int64(1), object(3), period[M](2)
# memory usage: 1.9+ MB

# %%
plt.title("연도 및 월별 체력단련장업 추이")
plt.xlabel("월")
plt.ylabel("업장 수")
df1.groupby(df1['인허가연월'])['인허가연월'].count().plot()
df1.groupby(df1['폐업,전출,휴업,취소,말소연월'])['폐업,전출,휴업,취소,말소여부'].sum().plot()
plt.xlim('1981-01', '2022-10')
plt.show()

# %%
df_Seoul = df1[df1['도로명전체주소'].str.contains('서울특별시', na = False)]

# %%
df_Seoul
# Out:
#                  사업장명      인허가일자    인허가취소일자     휴업시작일자     휴업종료일자 폐업일자  \
# 13           중곡문화체육센터 2008-10-24 2015-07-07        NaT        NaT  NaT
# 18         종로동부여성문화센터 2004-07-13 2015-08-24        NaT        NaT  NaT
# 19          종로청소년문화센터 2004-11-11 2015-08-24        NaT        NaT  NaT
# 23          동대문구민체육센터 2004-07-15 2015-09-04        NaT        NaT  NaT
# 207    초콜렛 휘트니스(무단폐업) 2010-11-02        NaT        NaT        NaT  NaT
# ...               ...        ...        ...        ...        ...  ...
# 20718             토브짐 2012-07-17        NaT 2020-03-23 2020-09-22  NaT
# 20727          휴 휘트니스 2006-01-23        NaT 2019-07-26 2019-12-31  NaT
# 20728   그랜드아쿠아24&휘트니스 2011-02-16        NaT 2021-08-19 2022-02-28  NaT
# 20746   (주)스포츠아트필피트니스 2008-11-04        NaT 2013-05-08 2013-09-01  NaT
# 20747       디앤브이 피트니스 2017-05-04        NaT 2019-10-10 2020-10-09  NaT
#
#                 영업상태명                                            도로명전체주소  \
# ...

# %%
plt.title("서울특별시 연도 및 월별 체력단련장업 추이")
plt.xlabel("월")
plt.ylabel("업장 수")
df_Seoul.groupby(df_Seoul['인허가연월'])['인허가연월'].count().plot()
df_Seoul.groupby(df_Seoul['폐업,전출,휴업,취소,말소연월'])['폐업,전출,휴업,취소,말소여부'].sum().plot()
plt.xlim('1989-01', '2022-10')
plt.show()
